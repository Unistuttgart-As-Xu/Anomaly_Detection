# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import folium
import glob, os


from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Anomaly_Detection/Input_2
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Anomaly_Detection/Input_2

# %%
path = './'
file = glob.glob(os.path.join(path, "AIS_2019_01_02.csv"))
print(file)
Data_region = []
for f in file:
    data = pd.read_csv(f)
    Data_region = data[(data["LAT"] < 49.44) & (data["LAT"] > 49.29) & (data["LON"] < -123.27) & (data["LON"] > -123.47)]
    Data_region.set_index('MMSI', inplace=True)
    Data_region.to_csv(f[:16]+"_region_1"+f[16:])
# Out:
# ['./AIS_2019_01_02.csv']
