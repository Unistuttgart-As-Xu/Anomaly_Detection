# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import folium
import glob, os


from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Anomaly_Detection/Real_Accident/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Anomaly_Detection/Real_Accident

# %%
path = './'
file = glob.glob(os.path.join(path, "AIS_2019_09_07.csv"))
print(file)
Data_region = []
for f in file:
    data = pd.read_csv(f)
    Data_region = data[(data["LAT"] < 31.19) & (data["LAT"] > 31.05) & (data["LON"] < -81.33) & (data["LON"] > -81.52)]
    Data_region.set_index('MMSI', inplace=True)
    Data_region.to_csv(f[:16]+"_region_2"+f[16:])
# Out:
# ['./AIS_2019_09_07.csv']
